# %% [markdown]
# # NAFNet Training on Colab / Kaggle
# This notebook runs the training pipeline.

# %%
# !pip install torch torchvision numpy opencv-python Pillow kornia

# %%
# Make sure you have uploaded the dataset or cloned your repository here
# Run the training script for 100 epochs
# !python scripts/train.py --noisy_dir competition_data/public/noisy --clean_dir competition_data/public/ground_truth --epochs 100 --batch_size 8 --patch_size 256
